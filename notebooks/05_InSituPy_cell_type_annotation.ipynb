# %% [markdown]
# # InSituPy demonstration - Cell type annotation

# %%
## The following code ensures that all functions and init files are reloaded before executions.
# %load_ext autoreload
# %autoreload 2

# %%
from pathlib import Path
from insitupy import InSituData, CACHE
import pandas as pd
from insitupy.utils import generate_mock_reference
import scanpy as sc
import numpy as np

# %% [markdown]
# ## Load Xenium data into `InSituData` object
#
# Now the Xenium data can be parsed by providing the data path to the `InSituPy` project folder.

# %%
insitupy_project = Path(CACHE / "out/demo_insitupy_project")

# %%
xd = InSituData.read(insitupy_project)

# %%
xd
# Out:
# InSituData
# Method:		Xenium
# Slide ID:	0001879
# Sample ID:	Replicate 1
# Path:		C:\Users\Anna Chernysheva\.cache\InSituPy\out\demo_insitupy_project
# Metadata file:	.ispy
#
# No modalities loaded.

# %%
xd.load_all(skip="transcripts")

# %%
xd
# Out:
# InSituData
# Method:		Xenium
# Slide ID:	0001879
# Sample ID:	Replicate 1
# Path:		C:\Users\Anna Chernysheva\.cache\InSituPy\out\demo_insitupy_project
# Metadata file:	.ispy
#     ➤ images
#        nuclei:	(25778, 35416)
#        CD20:	(25778, 35416)
#        HER2:	(25778, 35416)
#        HE:	(25778, 35416, 3)
#     ➤ cells
#        Main CellData: main
#        matrix
#            AnnData object with n_obs × n_vars = 157600 × 297
#            obs: 'transcript_counts', 'control_probe_counts', 'control_codeword_counts', 'total_counts', 'cell_area', 'nucleus_area', 'n_genes_by_counts', 'n_genes', 'leiden'
#            var: 'gene_ids', 'feature_types', 'genome', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'n_cells'
#            uns: 'leiden', 'leiden_colors', 'log1p', 'neighbors', 'pca', 'umap'
#            obsm: 'X_pca', 'X_umap', 'annotations', 'regions', 'spatial'
#            varm: 'PCs'
#            layers: 'counts', 'norm_counts'
#            obsp: 'connectivities', 'distances'
#        boundaries
#            BoundariesData object with 2 entries:
#                cells
#                nuclei
#
#     ➤ annotations
#        demo:	4 annotations, 2 classes ('Positive','Negative') ✔
#        demo2:	5 annotations, 3 classes ('Negative','Positive','Other') ✔
#        demo3:	7 annotations, 5 classes ('Stroma','Necrosis','Immune cells','unclassified','Tumor') ✔
#     ➤ regions
#        test:	7 regions, 5 classes ('Stroma','Necrosis','Immune cells','unclassified','Tumor') ✔
#        demo_regions:	3 regions, 3 classes ('Region1','Region2','Region3') ✔
#        TMA:	6 regions, 6 classes ('B-2','A-3','B-1','B-3','A-1','A-2') ✔

# %% [markdown]
# ## Prepare panel

# %%
# load panel annotated
panel = pd.read_csv("./demo_panel/Xenium_hBreast_v1_metadata.csv")
panel.head()
# Out:
#     Genes       Ensembl_ID  Num_Probesets  Codewords  \
# 0  ABCC11  ENSG00000121270              7          1
# 1   ACTA2  ENSG00000107796              8          1
# 2   ACTG2  ENSG00000163017              8          1
# 3   ADAM9  ENSG00000168615              8          1
# 4  ADGRE5  ENSG00000123146              8          1
#
#                    Annotation
# 0               Breast cancer
# 1         Smooth muscle cells
# 2  Breast myoepithelial cells
# 3      Breast glandular cells
# 4             Dendritic cells

# %%
# Remove ambiguous terms ("Immune cells")
panel = panel[~(panel["Annotation"] == "Immune cells")].copy()
panel = panel[~(panel["Annotation"] == "Epithelial cells")].copy()
panel["Annotation"].unique()
# Out:
# array(['Breast cancer', 'Smooth muscle cells',
#        'Breast myoepithelial cells', 'Breast glandular cells',
#        'Dendritic cells', 'Adipocytes', 'Macrophages',
#        'Endothelial cells', 'B cells', 'Fibroblasts', 'T cells',
#        'Monocytes', 'NK cells', 'Neutrophils', 'Mast cells',
#        'Myeloid cells', 'Plasma cells'], dtype=object)

# %% [markdown]
# # Cell annotation
#
# There are many ways to annotate cell types and which one is the best depends a lot on the specific dataset. Below we will introduce two marker gene-based approaches. As source for the marker genes we use the _Xenium In Situ_ panel but any other kind of marker gene resource would also be valid.
#
# Here is a list of available tools for cell type annotation/label transfer (only the first two are showcased here):
# - Decoupler (use statistical methods to test whether a set of marker genes is enriched in a particular cell  population (cluster)):
#   https://decoupler-py.readthedocs.io/en/latest/
# - TACCO (uses optimal transport methods to transfer labels from a reference to a target dataset): https://www.nature.com/articles/s41587-023-01657-3
# - Celltypist (automated cell type annotation tool for scRNA-seq datasets on the basis of logistic regression classifiers optimised by the stochastic gradient descent algorithm):
# https://www.celltypist.org, https://colab.research.google.com/github/Teichlab/celltypist/blob/main/docs/notebook/celltypist_tutorial.ipynb
#
# - SCANVI (semi-supervised model for single-cell transcriptomics data):
#   https://docs.scvi-tools.org/en/latest/user_guide/models/scanvi.html
#
# ## Option 1: Decoupler
#
# This approach is based on Over Representation Analysis (ORA) using the [`decoupler` package](https://decoupler-py.readthedocs.io/en/latest/index.html). A detailed description of this approach can be found [here](https://decoupler-py.readthedocs.io/en/latest/notebooks/cell_annotation.html).

# %%
# install decoupler
# !pip install decoupler==1.8.0
# Out:
# Requirement already satisfied: decoupler==1.8.0 in c:\users\anna chernysheva\.conda\envs\insitupy\lib\site-packages (1.8.0)
# Requirement already satisfied: numba<0.61.0,>=0.60.0 in c:\users\anna chernysheva\.conda\envs\insitupy\lib\site-packages (from decoupler==1.8.0) (0.60.0)
# Requirement already satisfied: numpy<2,>=1 in c:\users\anna chernysheva\.conda\envs\insitupy\lib\site-packages (from decoupler==1.8.0) (1.26.4)
# Requirement already satisfied: pandas<3.0.0,>=2.2.2 in c:\users\anna chernysheva\.conda\envs\insitupy\lib\site-packages (from decoupler==1.8.0) (2.2.3)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.4 in c:\users\anna chernysheva\.conda\envs\insitupy\lib\site-packages (from decoupler==1.8.0) (4.67.1)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.12.2 in c:\users\anna chernysheva\.conda\envs\insitupy\lib\site-packages (from decoupler==1.8.0) (4.12.2)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in c:\users\anna chernysheva\.conda\envs\insitupy\lib\site-packages (from numba<0.61.0,>=0.60.0->decoupler==1.8.0) (0.43.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\anna chernysheva\.conda\envs\insitupy\lib\site-packages (from pandas<3.0.0,>=2.2.2->decoupler==1.8.0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\anna chernysheva\.conda\envs\insitupy\lib\site-packages (from pandas<3.0.0,>=2.2.2->decoupler==1.8.0) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\anna chernysheva\.conda\envs\insitupy\lib\site-packages (from pandas<3.0.0,>=2.2.2->decoupler==1.8.0) (2025.1)
# Requirement already satisfied: colorama in c:\users\anna chernysheva\.conda\envs\insitupy\lib\site-packages (from tqdm<5.0.0,>=4.66.4->decoupler==1.8.0) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\anna chernysheva\.conda\envs\insitupy\lib\site-packages (from python-dateutil>=2.8.2->pandas<3.0.0,>=2.2.2->decoupler==1.8.0) (1.17.0)

# %%
import decoupler as dc

# %% [markdown]
# ### Run Over Representation Analysis (ORA)

# %%
dc.run_ora(mat=xd.cells["main"].matrix,
           net=panel,
           source='Annotation',
           target='Genes', min_n=3,
           verbose=True, use_raw=False)
# Out:
# Running ora on mat with 157600 samples and 297 targets for 14 sources.
#   0%|          | 0/157600 [00:00<?, ?it/s]

# %%
xd.cells["main"].matrix.obsm['ora_estimate']
# Out:
# source  Adipocytes   B cells  Breast cancer  Breast glandular cells  \
# 2             -0.0  1.730644       8.082256               11.948087
# 5             -0.0  1.730644       3.563019               14.476218
# 8             -0.0 -0.000000       3.563019               11.948087
# 10            -0.0 -0.000000       8.082256                5.132052
# 13            -0.0  1.730644      10.577904                5.132052
# ...            ...       ...            ...                     ...
# 167776        -0.0 -0.000000      18.854425                7.265299
# 167777        -0.0 -0.000000      15.969095                9.541912
# 167778        -0.0 -0.000000      18.854425                9.541912
# 167779        -0.0 -0.000000      15.969095                7.265299
# 167780        -0.0 -0.000000      18.854425                5.132052
#
# source  Breast myoepithelial cells  Dendritic cells  Endothelial cells  \
# 2                         4.261077        -0.000000               -0.0
# 5                        -0.000000        -0.000000               -0.0
# 8                         1.950975        -0.000000               -0.0
# 10                        1.950975         2.171912               -0.0
# 13                        6.811197        -0.000000               -0.0
# ...                            ...              ...                ...
# 167776                    1.950975        -0.000000               -0.0
# 167777                    4.261077        -0.000000               -0.0
# 167778                   -0.000000        -0.000000               -0.0
# 167779                    1.950975        -0.000000               -0.0
# 167780                   -0.000000        -0.000000               -0.0
#
# source  Fibroblasts  Macrophages  Mast cells  Monocytes  NK cells  \
# 2         -0.000000    -0.000000   -0.000000       -0.0 -0.000000
# 5          1.980786     1.730644   -0.000000       -0.0 -0.000000
# 8          1.980786    -0.000000   -0.000000       -0.0  2.222913
# 10        -0.000000     3.807027    2.648122       -0.0  2.222913
# 13        -0.000000     1.730644   -0.000000       -0.0 -0.000000
# ...             ...          ...         ...        ...       ...
# 167776    -0.000000    -0.000000   -0.000000       -0.0 -0.000000
# 167777    -0.000000    -0.000000   -0.000000       -0.0 -0.000000
# 167778    -0.000000    -0.000000   -0.000000       -0.0 -0.000000
# 167779    -0.000000    -0.000000   -0.000000       -0.0 -0.000000
# 167780    -0.000000    -0.000000   -0.000000       -0.0 -0.000000
#
# source  Smooth muscle cells   T cells
# 2                 -0.000000 -0.000000
# 5                 -0.000000 -0.000000
# 8                  1.980786  3.563019
# 10                -0.000000  1.611284
# 13                -0.000000  1.611284
# ...                     ...       ...
# 167776            -0.000000 -0.000000
# 167777            -0.000000 -0.000000
# 167778            -0.000000 -0.000000
# 167779            -0.000000 -0.000000
# 167780            -0.000000 -0.000000
#
# [157600 rows x 14 columns]

# %%
acts = dc.get_acts(xd.cells["main"].matrix, obsm_key='ora_estimate')

# We need to remove inf and set them to the maximum value observed for pvals=0
acts_v = acts.X.ravel()
max_e = np.nanmax(acts_v[np.isfinite(acts_v)])
acts.X[~np.isfinite(acts.X)] = max_e

# %%
acts
# Out:
# AnnData object with n_obs × n_vars = 157600 × 14
#     obs: 'transcript_counts', 'control_probe_counts', 'control_codeword_counts', 'total_counts', 'cell_area', 'nucleus_area', 'n_genes_by_counts', 'n_genes', 'leiden'
#     uns: 'leiden', 'leiden_colors', 'log1p', 'neighbors', 'pca', 'umap'
#     obsm: 'X_pca', 'X_umap', 'annotations', 'regions', 'spatial', 'ora_estimate', 'ora_pvals'

# %% [markdown]
# ### Identify top predicted cell types per cluster

# %%
df = dc.rank_sources_groups(acts, groupby='leiden', reference='rest', method='t-test_overestim_var')

# %%
df
# Out:
#     group reference                       names   statistic  meanchange  \
# 0       0      rest               Breast cancer  190.710233    6.860917
# 1       0      rest      Breast glandular cells  187.644424    4.171648
# 2       0      rest                  Mast cells  -15.951901   -0.049007
# 3       0      rest  Breast myoepithelial cells  -23.426186   -0.358969
# 4       0      rest                   Monocytes  -42.778872   -0.162306
# ..    ...       ...                         ...         ...         ...
# 191     9      rest                  Adipocytes  -18.904398   -0.308321
# 192     9      rest                     B cells  -22.172707   -0.652371
# 193     9      rest                 Macrophages  -23.197027   -1.040547
# 194     9      rest                 Fibroblasts  -26.829464   -1.915370
# 195     9      rest                     T cells  -38.295540   -2.590824
#
#              pvals      pvals_adj
# 0     0.000000e+00   0.000000e+00
# 1     0.000000e+00   0.000000e+00
# 2     4.319371e-57   4.319371e-57
# 3    8.772671e-121  9.447492e-121
# 4     0.000000e+00   0.000000e+00
# ..             ...            ...
# 191   1.332852e-77   2.332491e-77
# 192  4.516891e-105  1.053941e-104
# 193  1.274109e-115  3.567505e-115
# 194  1.272600e-151  4.454098e-151
# 195  2.044136e-287  1.430895e-286
#
# [196 rows x 7 columns]

# %%
# transfer annotations to clusters
annotation_dict = df.groupby('group').head(1).set_index('group')['names'].to_dict()
annotation_dict
# Out:
# {'0': 'Breast cancer',
#  '1': 'T cells',
#  '10': 'B cells',
#  '11': 'Macrophages',
#  '12': 'B cells',
#  '13': 'Breast glandular cells',
#  '2': 'Fibroblasts',
#  '3': 'Breast cancer',
#  '4': 'T cells',
#  '5': 'Breast cancer',
#  '6': 'Macrophages',
#  '7': 'Endothelial cells',
#  '8': 'Smooth muscle cells',
#  '9': 'Breast myoepithelial cells'}

# %%
xd.cells["main"].matrix.obs['cell_type_dc'] = [annotation_dict[clust] for clust in xd.cells["main"].matrix.obs['leiden']]

# %%
sc.pl.umap(xd.cells["main"].matrix, color='cell_type_dc', save="_cell_type_dc.pdf")
# Out:
# WARNING: saving figure to file figures\umap_cell_type_dc.pdf

# %% [markdown]
# ### Caution!
#
# This cell type annotation is only a demonstration and most probably contains inaccuracies. Cell type annotation needs to be done very carefully and results need to be double checked with pathological experts!

# %% [markdown]
# ## Option 2: TACCO annotation transfer using a mock reference
#
# For demonstration purposes, here we use the Xenium panel used for the breast cancer demo dataset to generate a mock single-cell RNA-seq reference.

# %%
# install tacco
# !pip install tacco
# Out:
# Collecting tacco
#   Downloading tacco-0.4.0.post1-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: requests in c:\users\ge37voy\appdata\local\miniconda3\envs\test\lib\site-packages (from tacco) (2.32.3)
# Requirement already satisfied: joblib in c:\users\ge37voy\appdata\local\miniconda3\envs\test\lib\site-packages (from tacco) (1.4.2)
# Requirement already satisfied: numba>=0.51.2 in c:\users\ge37voy\appdata\local\miniconda3\envs\test\lib\site-packages (from tacco) (0.60.0)
# Requirement already satisfied: numpy in c:\users\ge37voy\appdata\local\miniconda3\envs\test\lib\site-packages (from tacco) (1.26.4)
# Requirement already satisfied: matplotlib!=3.7 in c:\users\ge37voy\appdata\local\miniconda3\envs\test\lib\site-packages (from tacco) (3.9.4)
# Requirement already satisfied: seaborn in c:\users\ge37voy\appdata\local\miniconda3\envs\test\lib\site-packages (from tacco) (0.13.2)
# Collecting sparse-dot-mkl>=0.7.3 (from tacco)
#   Downloading sparse_dot_mkl-0.9.7-py3-none-any.whl.metadata (7.6 kB)
# Requirement already satisfied: scanpy>=1.7.0 in c:\users\ge37voy\appdata\local\miniconda3\envs\test\lib\site-packages (from tacco) (1.10.3)
# Requirement already satisfied: statsmodels in c:\users\ge37voy\appdata\local\miniconda3\envs\test\lib\site-packages (from tacco) (0.14.4)
# Requirement already satisfied: anndata>=0.9.0 in c:\users\ge37voy\appdata\local\miniconda3\envs\test\lib\site-packages (from tacco) (0.10.9)
# Requirement already satisfied: pandas>=1.1.0 in c:\users\ge37voy\appdata\local\miniconda3\envs\test\lib\site-packages (from tacco) (2.2.3)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\ge37voy\appdata\local\miniconda3\envs\test\lib\site-packages (from tacco) (1.13.1)
# Collecting mkl (from tacco)
#   Downloading mkl-2025.0.1-py2.py3-none-win_amd64.whl.metadata (1.4 kB)
# Collecting mkl-service (from tacco)
#   Downloading mkl_service-2.4.2-0-cp39-cp39-win_amd64.whl.metadata (2.6 kB)
# Requirement already satisfied: scikit-learn in c:\users\ge37voy\appdata\local\miniconda3\envs\test\lib\site-packages (from tacco) (1.6.1)
# Requirement already satisfied: threadpoolctl in c:\users\ge37voy\appdata\local\miniconda3\envs\test\lib\site-packages (from tacco) (3.5.0)
# Collecting pyamg (from tacco)
#   Downloading pyamg-5.2.1-cp39-cp39-win_amd64.whl.metadata (8.3 kB)
# Requirement already satisfied: array-api-compat!=1.5,>1.4 in c:\users\ge37voy\appdata\local\miniconda3\envs\test\lib\site-packages (from anndata>=0.9.0->tacco) (1.10.0)
# Requirement already satisfied: exceptiongroup in c:\users\ge37voy\appdata\local\miniconda3\envs\test\lib\site-packages (from anndata>=0.9.0->tacco) (1.2.2)
# Requirement already satisfied: h5py>=3.1 in c:\users\ge37voy\appdata\local\miniconda3\envs\test\lib\site-packages (from anndata>=0.9.0->tacco) (3.12.1)
# Requirement already satisfied: natsort in c:\users\ge37voy\appdata\local\miniconda3\envs\test\lib\site-packages (from anndata>=0.9.0->tacco) (8.4.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\ge37voy\appdata\local\miniconda3\envs\test\lib\site-packages (from anndata>=0.9.0->tacco) (24.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ge37voy\appdata\local\miniconda3\envs\test\lib\site-packages (from matplotlib!=3.7->tacco) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\ge37voy\appdata\local\miniconda3\envs\test\lib\site-packages (from matplotlib!=3.7->tacco) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ge37voy\appdata\local\miniconda3\envs\test\lib\site-packages (from matplotlib!=3.7->tacco) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\ge37voy\appdata\local\miniconda3\envs\test\lib\site-packages (from matplotlib!=3.7->tacco) (1.4.7)
# Requirement already satisfied: pillow>=8 in c:\users\ge37voy\appdata\local\miniconda3\envs\test\lib\site-packages (from matplotlib!=3.7->tacco) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ge37voy\appdata\local\miniconda3\envs\test\lib\site-packages (from matplotlib!=3.7->tacco) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ge37voy\appdata\local\miniconda3\envs\test\lib\site-packages (from matplotlib!=3.7->tacco) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\ge37voy\appdata\local\miniconda3\envs\test\lib\site-packages (from matplotlib!=3.7->tacco) (6.5.2)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in c:\users\ge37voy\appdata\local\miniconda3\envs\test\lib\site-packages (from numba>=0.51.2->tacco) (0.43.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ge37voy\appdata\local\miniconda3\envs\test\lib\site-packages (from pandas>=1.1.0->tacco) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\ge37voy\appdata\local\miniconda3\envs\test\lib\site-packages (from pandas>=1.1.0->tacco) (2025.1)
# Requirement already satisfied: get-annotations in c:\users\ge37voy\appdata\local\miniconda3\envs\test\lib\site-packages (from scanpy>=1.7.0->tacco) (0.1.2)
# Requirement already satisfied: legacy-api-wrap>=1.4 in c:\users\ge37voy\appdata\local\miniconda3\envs\test\lib\site-packages (from scanpy>=1.7.0->tacco) (1.4.1)
# Requirement already satisfied: networkx>=2.7 in c:\users\ge37voy\appdata\local\miniconda3\envs\test\lib\site-packages (from scanpy>=1.7.0->tacco) (3.2.1)
# Requirement already satisfied: patsy in c:\users\ge37voy\appdata\local\miniconda3\envs\test\lib\site-packages (from scanpy>=1.7.0->tacco) (1.0.1)
# Requirement already satisfied: pynndescent>=0.5 in c:\users\ge37voy\appdata\local\miniconda3\envs\test\lib\site-packages (from scanpy>=1.7.0->tacco) (0.5.13)
# Requirement already satisfied: session-info in c:\users\ge37voy\appdata\local\miniconda3\envs\test\lib\site-packages (from scanpy>=1.7.0->tacco) (1.0.0)
# Requirement already satisfied: tqdm in c:\users\ge37voy\appdata\local\miniconda3\envs\test\lib\site-packages (from scanpy>=1.7.0->tacco) (4.67.1)
# Requirement already satisfied: umap-learn!=0.5.0,>=0.5 in c:\users\ge37voy\appdata\local\miniconda3\envs\test\lib\site-packages (from scanpy>=1.7.0->tacco) (0.5.7)
# Collecting intel-openmp>=2024 (from mkl->tacco)
#   Downloading intel_openmp-2025.0.5-py2.py3-none-win_amd64.whl.metadata (1.3 kB)
# Collecting tbb==2022.* (from mkl->tacco)
#   Downloading tbb-2022.0.0-py3-none-win_amd64.whl.metadata (1.1 kB)
# Collecting tcmlib==1.* (from tbb==2022.*->mkl->tacco)
#   Downloading tcmlib-1.2.0-py2.py3-none-win_amd64.whl.metadata (1.0 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ge37voy\appdata\local\miniconda3\envs\test\lib\site-packages (from requests->tacco) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ge37voy\appdata\local\miniconda3\envs\test\lib\site-packages (from requests->tacco) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ge37voy\appdata\local\miniconda3\envs\test\lib\site-packages (from requests->tacco) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ge37voy\appdata\local\miniconda3\envs\test\lib\site-packages (from requests->tacco) (2025.1.31)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\ge37voy\appdata\local\miniconda3\envs\test\lib\site-packages (from importlib-resources>=3.2.0->matplotlib!=3.7->tacco) (3.21.0)
# Collecting intel-cmplr-lib-ur==2025.0.5 (from intel-openmp>=2024->mkl->tacco)
#   Downloading intel_cmplr_lib_ur-2025.0.5-py2.py3-none-win_amd64.whl.metadata (1.3 kB)
# Collecting umf==0.9.* (from intel-cmplr-lib-ur==2025.0.5->intel-openmp>=2024->mkl->tacco)
#   Downloading umf-0.9.1-py2.py3-none-win_amd64.whl.metadata (1.1 kB)
# Requirement already satisfied: six>=1.5 in c:\users\ge37voy\appdata\local\miniconda3\envs\test\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3
MB 7.0 MB/s eta 0:00:01
#    ---------------------------------------- 3.7/3.7 MB 6.1 MB/s eta 0:00:00
# Downloading intel_cmplr_lib_ur-2025.0.5-py2.py3-none-win_amd64.whl (1.2 MB)
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    ---------------------------------------- 1.2/1.2 MB 5.8 MB/s eta 0:00:00
# Downloading umf-0.9.1-py2.py3-none-win_amd64.whl (72 kB)
# Installing collected packages: tcmlib, umf, tbb, sparse-dot-mkl, pyamg, intel-cmplr-lib-ur, intel-openmp, mkl, mkl-service, tacco
# Successfully installed intel-cmplr-lib-ur-2025.0.5 intel-openmp-2025.0.5 mkl-2025.0.1 mkl-service-2.4.2 pyamg-5.2.1 sparse-dot-mkl-0.9.7 tacco-0.4.0.post1 tbb-2022.0.0 tcmlib-1.2.0 umf-0.9.1

# %%
import tacco as tc

# %%
# generate mock reference from gene panel
reference = generate_mock_reference(panel, annotation_column="Annotation", gene_column="Genes")
reference
# Out:
# AnnData object with n_obs × n_vars = 17 × 273
#     obs: 'Annotation'

# %%
# set counts location
xd.cells["main"].matrix.uns["counts_location"] = ['layer', 'counts']

# %%
# This is the annotation step. OT is our own annotation method, but theres multiple like rctd implemented in Tacco
# Theres also multiple parameters one could adjust, i ran everything with default
tc.tl.annotate(adata=xd.cells["main"].matrix,
               reference=reference,
               annotation_key='Annotation',
               counts_location=None,  # if None it looks in `.uns["counts_location"]`
               result_key='OT',
               assume_valid_counts=False
               )
# Out:
# Starting preprocessing
# Annotation profiles were not found in `reference.varm["Annotation"]`. Constructing reference profiles with `tacco.preprocessing.construct_reference_profiles` and default arguments...
# Finished preprocessing in 1.72 seconds.
# Starting annotation of data with shape (163565, 273) and a reference of shape (17, 273) using the following wrapped method:
# +- platform normalization: platform_iterations=0, gene_keys=Annotation, normalize_to=adata
#    +- multi center: multi_center=None multi_center_amplitudes=True
#       +- bisection boost: bisections=4, bisection_divisor=3
#          +- core: method=OT annotation_prior=None
# mean,std( rescaling(gene) )  105.62331501831503 191.09373482455533
# bisection run on 1
# bisection run on 0.6666666666666667
# bisection run on 0.4444444444444444
# bisection run on 0.2962962962962963
# bisection run on 0.19753086419753085
# bisection run on 0.09876543209876543
# Finished annotation in 18.74 seconds.
# AnnData object with n_obs × n_vars = 163565 × 313
#     obs: 'transcript_counts', 'control_probe_counts', 'control_codeword_counts', 'total_counts', 'cell_area', 'nucleus_area', 'n_genes', 'leiden', 'cell_type_dc'
#     var: 'gene_ids', 'feature_types', 'genome'
#     uns: 'leiden', 'leiden_colors', 'log1p', 'neighbors', 'pca', 'umap', 'cell_type_dc_colors', 'counts_location'
#     obsm: 'X_pca', 'X_umap', 'annotations', 'regions', 'spatial', 'ora_estimate', 'ora_pvals', 'OT'
#     varm: 'PCs', 'OT'
#     layers: 'counts', 'norm_counts'
#     obsp: 'connectivities', 'distances'

# %%
# Tacco annotate returns non-absolute cell type percentages for each cell, since in other spatial methods
# cells can overlap on the measurement spots. This is to get the absolute annotation for each cell
tc.utils.get_maximum_annotation(xd.cells["main"].matrix, 'OT', result_key='cell_type_tacco')
# Out:
# AnnData object with n_obs × n_vars = 163565 × 313
#     obs: 'transcript_counts', 'control_probe_counts', 'control_codeword_counts', 'total_counts', 'cell_area', 'nucleus_area', 'n_genes', 'leiden', 'cell_type_dc', 'cell_type_tacco'
#     var: 'gene_ids', 'feature_types', 'genome'
#     uns: 'leiden', 'leiden_colors', 'log1p', 'neighbors', 'pca', 'umap', 'cell_type_dc_colors', 'counts_location'
#     obsm: 'X_pca', 'X_umap', 'annotations', 'regions', 'spatial', 'ora_estimate', 'ora_pvals', 'OT'
#     varm: 'PCs', 'OT'
#     layers: 'counts', 'norm_counts'
#     obsp: 'connectivities', 'distances'

# %%
xd.cells["main"].matrix
# Out:
# AnnData object with n_obs × n_vars = 163565 × 313
#     obs: 'transcript_counts', 'control_probe_counts', 'control_codeword_counts', 'total_counts', 'cell_area', 'nucleus_area', 'n_genes', 'leiden', 'cell_type_dc', 'cell_type_tacco'
#     var: 'gene_ids', 'feature_types', 'genome'
#     uns: 'leiden', 'leiden_colors', 'log1p', 'neighbors', 'pca', 'umap', 'cell_type_dc_colors', 'counts_location'
#     obsm: 'X_pca', 'X_umap', 'annotations', 'regions', 'spatial', 'ora_estimate', 'ora_pvals', 'OT'
#     varm: 'PCs', 'OT'
#     layers: 'counts', 'norm_counts'
#     obsp: 'connectivities', 'distances'

# %%
sc.pl.umap(xd.cells["main"].matrix, color="cell_type_tacco", save="_cell_type_tacco.pdf")
# Out:
# WARNING: saving figure to file figures\umap_cell_type_tacco.pdf

# %% [markdown]
# ## Visualization in napari
#
# The cell type annotation can be selected in the "Show data" widget on the right under "observation" and then be displayed with the "Add" button:
#
# <left><img src="./demo_screenshots/napari_cell_annotation_marked.jpg" width="1000"/></left>
#
# When the the correct layer is selected in the layer list on the left, it is possible to hover with the mouse onto a cell and see the annotation of this cell on the bottom left under "value".

# %% [markdown]
# ### Investigate the cellular composition of annotations and regions

# %%
xd.show()

# %%
xd.import_annotations(
    files="./demo_annotations/demo_annotations.geojson",
    keys="Demo",
    scale_factor=0.2125
)

# %%
xd.import_regions(
    files="./demo_regions/demo_regions.geojson",
    keys="Demo",
    scale_factor=0.2125
)

# %%
from insitupy.plotting import plot_cellular_composition

# %%
plot_cellular_composition(
    data=xd, cell_type_col="cell_type_dc",
    key="Demo", modality="regions", max_cols=3, show_labels=True,
    savepath="figures/cell_composition_regions_Demo_dc.pdf"
)
# Out:
# Regions with key 'Demo' have already been assigned to the dataset.
# Saving figure to file figures/cell_composition_regions_Demo_dc.pdf
# Saved.

# %%
plot_cellular_composition(
    data=xd, cell_type_col="cell_type_tacco",
    key="Demo", modality="regions", max_cols=3, show_labels=True,
    savepath="figures/cell_composition_regions_Demo_tacco.pdf"
)
# Out:
# Regions with key 'Demo' have already been assigned to the dataset.
# Saving figure to file figures/cell_composition_regions_Demo_tacco.pdf
# Saved.

# %%
plot_cellular_composition(
    data=xd, cell_type_col="cell_type_dc",
    key="Demo", modality="annotations", max_cols=3, show_labels=True,
    savepath="figures/cell_composition_annotations_Demo_dc.pdf"
)
# Out:
# Assigning key 'Demo'...
# Added results to `.cells.matrix.obsm['annotations']
# Saving figure to file figures/cell_composition_annotations_Demo_dc.pdf
# Saved.

# %%
plot_cellular_composition(
    data=xd, cell_type_col="cell_type_dc",
    key="TMA", modality="regions", max_cols=3, show_labels=True,
    savepath="figures/cell_composition_TMA_dc.pdf"
)
# Out:
# Regions with key 'TMA' have already been assigned to the dataset.
# Saving figure to file figures/cell_composition_TMA_dc.pdf
# Saved.

# %% [markdown]
# ## Save results

# %%
xd.save()
# Out:
# Updating project in C:\Users\ge37voy\.cache\InSituPy\out\demo_insitupy_project
# 	Updating cells...
# 	Updating annotations...
# 	Updating regions...
# Saved.
